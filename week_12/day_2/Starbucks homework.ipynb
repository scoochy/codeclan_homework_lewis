# %%
import pandas as pd

# %%
drinks_content = pd.read_csv("data/starbucks_drinkMenu_expanded.csv")

# %%
drinks_content
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
drinks_content.shape
# Out:
# (242, 18)

# %%
drinks_content.columns
# Out:
# Index(['Beverage_category', 'Beverage', 'Beverage_prep', 'Calories',
#        ' Total Fat (g)', 'Trans Fat (g) ', 'Saturated Fat (g)', ' Sodium (mg)',
#        ' Total Carbohydrates (g) ', 'Cholesterol (mg)', ' Dietary Fibre (g)',
#        ' Sugars (g)', ' Protein (g) ', 'Vitamin A (% DV) ', 'Vitamin C (% DV)',
#        ' Calcium (% DV) ', 'Iron (% DV) ', 'Caffeine (mg)'],
#       dtype='object')

# %%
drinks_content["max"] = max(drinks_content["Calories"])
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
drinks_content.describe().Calories
# Out:
# count    242.000000
# mean     193.871901
# std      102.863303
# min        0.000000
# 25%      120.000000
# 50%      185.000000
# 75%      260.000000
# max      510.000000
# Name: Calories, dtype: float64

# %%
drinks = drinks_content.loc[:, ["Beverage", "Beverage_category", "Beverage_prep", "Calories"]].copy()
drinks
# Out:
#                                          Beverage           Beverage_category  \
# 0                                   Brewed Coffee                      Coffee
# 1                                   Brewed Coffee                      Coffee
# 2                                   Brewed Coffee                      Coffee
# 3                                   Brewed Coffee                      Coffee
# 4                                     Caffè Latte     Classic Espresso Drinks
# ..                                            ...                         ...
# 237  Strawberries & Crème (Without Whipped Cream)  Frappuccino® Blended Crème
# 238          Vanilla Bean (Without Whipped Cream)  Frappuccino® Blended Crème
# 239          Vanilla Bean (Without Whipped Cream)  Frappuccino® Blended Crème
# 240          Vanilla Bean (Without Whipped Cream)  Frappuccino® Blended Crème
# 241          Vanilla Bean (Without Whipped Cream)  Frappuccino® Blended Crème
#
# ...

# %%
drinks.isnull().sum()
# Out:
# Beverage_category    0
# Beverage             0
# Beverage_prep        0
# Calories             0
# dtype: int64

# %%
drinks.loc[:, "calorie_diff"] = 135 - drinks["Calories"]

# %%
drinks
# Out:
#                        Beverage_category  \
# 0                                 Coffee
# 1                                 Coffee
# 2                                 Coffee
# 3                                 Coffee
# 4                Classic Espresso Drinks
# ...                                  ...
# 238           Frappuccino® Blended Crème
# 239           Frappuccino® Blended Crème
# 240           Frappuccino® Blended Crème
# 241           Frappuccino® Blended Crème
# calorie_diff                         NaN
#
#                                           Beverage       Beverage_prep  \
# 0                                    Brewed Coffee               Short
# 1                                    Brewed Coffee                Tall
# 2                                    Brewed Coffee              Grande
# 3                                    Brewed Coffee               Venti
# 4                                      Caffè Latte   Short Nonfat Milk
# ...

# %%
group_means = drinks.groupby("Beverage_category").mean().Calories
group_means
# Out:
# Beverage_category
# Classic Espresso Drinks              140.172414
# Coffee                                 4.250000
# Frappuccino® Blended Coffee          276.944444
# Frappuccino® Blended Crème           233.076923
# Frappuccino® Light Blended Coffee    162.500000
# Shaken Iced Beverages                114.444444
# Signature Espresso Drinks            250.000000
# Smoothies                            282.222222
# Tazo® Tea Drinks                     177.307692
# Name: Calories, dtype: float64

# %%
group_means > drinks["Calories"].mean()
# Out:
# Beverage_category
# Classic Espresso Drinks              False
# Coffee                               False
# Frappuccino® Blended Coffee           True
# Frappuccino® Blended Crème            True
# Frappuccino® Light Blended Coffee    False
# Shaken Iced Beverages                False
# Signature Espresso Drinks             True
# Smoothies                             True
# Tazo® Tea Drinks                     False
# Name: Calories, dtype: bool

# %%
drinks_content.sort_values("Calories")
drinks_content
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %% [markdown]
# Brewed Coffee is the best type of beverage to get on a diet

# %%
espresso_drinks = drinks[drinks["Beverage_category"] == "Classic Espresso Drinks"]
espresso_drinks
# Out:
#           Beverage_category                                  Beverage  \
# 4   Classic Espresso Drinks                               Caffè Latte
# 5   Classic Espresso Drinks                               Caffè Latte
# 6   Classic Espresso Drinks                               Caffè Latte
# 7   Classic Espresso Drinks                               Caffè Latte
# 8   Classic Espresso Drinks                               Caffè Latte
# 9   Classic Espresso Drinks                               Caffè Latte
# 10  Classic Espresso Drinks                               Caffè Latte
# 11  Classic Espresso Drinks                               Caffè Latte
# 12  Classic Espresso Drinks                               Caffè Latte
# 13  Classic Espresso Drinks                               Caffè Latte
# 14  Classic Espresso Drinks                               Caffè Latte
# 15  Classic Espresso Drinks                               Caffè Latte
# ...

# %%
espresso_drinks.groupby("Beverage").mean().Calories.sort_values(ascending = False)
# Out:
# Beverage
# Caffè Mocha (Without Whipped Cream)         210.000000
# Vanilla Latte (Or Other Flavoured Latte)    195.833333
# Caffè Latte                                 139.166667
# Skinny Latte (Any Flavour)                  110.000000
# Cappuccino                                   90.000000
# Caffè Americano                              13.750000
# Espresso                                      7.500000
# Name: Calories, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
ordered_data = drinks.groupby("Beverage_category")["Calories"].mean().sort_values(ascending = False).index
ordered_data
# Out:
# Index(['Smoothies', 'Frappuccino® Blended Coffee', 'Signature Espresso Drinks',
#        'Frappuccino® Blended Crème', 'Tazo® Tea Drinks',
#        'Frappuccino® Light Blended Coffee', 'Classic Espresso Drinks',
#        'Shaken Iced Beverages', 'Coffee'],
#       dtype='object', name='Beverage_category')

# %%
sns.barplot(data = drinks, x = "Calories", y = "Beverage_category", order = ordered_data, ci = False);
